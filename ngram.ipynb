# %% [markdown]
# # Week 3 Assignment: Implementing N-grams with NLTK
#
# **Task:**
# Create N-grams for various N across multiple sentences using at least 1 or 2 sentences to apply multiple N values.
# ***

# %% [markdown]
# # Environment Setup & Library Install

# %%
import pandas as pd
import nltk
import spacy

# %% [markdown]
# ***
# # Dataset Collection
# - Select a sample text with at least one or two sentences.
#     - *Sample text collected from: https://reedsy.com/short-stories/*

# %%
text_segments = {
    "Segment 1 - The Funeral and the Feast": """
    The old woman in a white lace dress had appeared in Claudia’s dream three 
    days before her grandfather died. The dress was so crisp, so white, so 
    beautiful it actually frightened her – not the kind of fear that makes you 
    want to pull the blanket over your head, but the kind that roots you to the 
    spot and freezes the blood coursing through your veins. She had woken from 
    this dream with certainty. She knew what was coming. And she had been right.
    """,

    "Segment 2 - The Funeral and the Feast": """
    Claudia noticed her mother and said nothing. She had spent the whole day calculating 
    the right gesture – a hand on the arm, a quiet word of comfort – and kept coming up empty.
    For anyone else in mourning, she would have known exactly what to do and say. For her mother, 
    the wires crossed somewhere. They seemed to always be reaching for each other but missing the 
    mark by an inch.    
    """,

    "Segment 3 - The Funeral and the Feast": """
    On her left sat ninety three years old Victor, who had been friends with her 
    grandfather for longer than Claudia’s parents had been alive. He was the spitting 
    image of French movie star from the ‘80s and ‘90s, the beautiful Alain Delon. 
    The man was over six feet tall, full head of silver hair, cleanly shaven and looking 
    dapper in his leather jacket and suit pants. It was easy for Claudia to assume that 
    her grandfather and this man were quite the Casanovas back in the day.    
    """
}

# %% [markdown]
# ***
# # Tokenization
# - Tokenize the selected text into sentences and words using NLTK’s tokenizer.

# %%
# Convert to lowercase; Remove punctuation; Split into sentences and words

def preprocess_text(text):
    #Split into sentences
    sentences = nltk.sent_tokenize(text)

    # Convert to lowercase
    cleaned_text = text.lower()
    
    # Remove punctuation
    cleaned_text = ''.join(
        char for char in cleaned_text 
        if char.isalnum() or char.isspace()
    )
    
    # Split into words
    words = nltk.word_tokenize(cleaned_text)
    
    return sentences, words

# %% [markdown]
# ***
# # Generate N-grams
# - Create N-grams for various values of N (e.g., 1, 2, 3)

# %%
# N-grams for various n values (1, 2, 3)

def generate_ngrams(words, n): # Generate n-grams for a list of words
    ngrams = list(nltk.ngrams(words, n)) # Generate n-grams using nltk
    return ngrams # Return the list of n-grams

# %%
# Extract n-grams for each segment
ngram_results = {}
for segment_name, text in text_segments.items():
    sentences, words = preprocess_text(text)
    ngram_results[segment_name] = {
        'unigrams': generate_ngrams(words, 1),
        'bigrams': generate_ngrams(words, 2),
        'trigrams': generate_ngrams(words, 3)
    }

# %%
# Show All n-grams for Each Segment
for segment_name, ngrams in ngram_results.items():
    print(f"{segment_name} - Unigrams:")
    print(ngrams['unigrams'])
    print(f"{segment_name} - Bigrams:")
    print(ngrams['bigrams'])
    print(f"{segment_name} - Trigrams:")
    print(ngrams['trigrams'])
    print("\n")
# Out:
# Segment 1 - The Funeral and the Feast - Unigrams:
# [('the',), ('old',), ('woman',), ('in',), ('a',), ('white',), ('lace',), ('dress',), ('had',), ('appeared',), ('in',), ('claudias',), ('dream',), ('three',), ('days',), ('before',), ('her',), ('grandfather',), ('died',), ('the',), ('dress',), ('was',), ('so',), ('crisp',), ('so',), ('white',), ('so',), ('beautiful',), ('it',), ('actually',), ('frightened',), ('her',), ('not',), ('the',), ('kind',), ('of',), ('fear',), ('that',), ('makes',), ('you',), ('want',), ('to',), ('pull',), ('the',), ('blanket',), ('over',), ('your',), ('head',), ('but',), ('the',), ('kind',), ('that',), ('roots',), ('you',), ('to',), ('the',), ('spot',), ('and',), ('freezes',), ('the',), ('blood',), ('coursing',), ('through',), ('your',), ('veins',), ('she',), ('had',), ('woken',), ('from',), ('this',), ('dream',), ('with',), ('certainty',), ('she',), ('knew',), ('what',), ('was',), ('coming',), ('and',), ('she',), ('had',), ('been',), ('right',)]
# Segment 1 - The Funeral and the Feast - Bigrams:
# [('the', 'old'), ('old', 'woman'), ('woman', 'in'), ('in', 'a'), ('a', 'white'), ('white', 'lace'), ('lace', 'dress'), ('dress', 'had'), ('had', 'appeared'), ('appeared', 'in'), ('in', 'claudias'), ('claudias', 'dream'), ('dream', 'three'), ('three', 'days'), ('days', 'before'), ('before', 'her'), ('her', 'grandfather'), ('grandfather', 'died'), ('died', 'the'), ('the', 'dress'), ('dress', 'was'), ('was', 'so'), ('so', 'crisp'), ('crisp', 'so'), ('so', 'white'), ('white', 'so'), ('so', 'beautiful'), ('beautiful', 'it'), ('it', 'actually'), ('actually', 'frightened'), ('frightened', 'her'), ('her', 'not'), ('not', 'the'), ('the', 'kind'), ('kind', 'of'), ('of', 'fear'), ('fear', 'that'), ('that', 'makes'), ('makes', 'you'), ('you', 'want'), ('want', 'to'), ('to', 'pull'), ('pull', 'the'), ('the', 'blanket'), ('blanket', 'over'), ('over', 'your'), ('your', 'head'), ('head', 'but'), ('but', 'the'), ('the', 'kind'), ('kind', 'that'), ('that', 'roots'), ('roots', 'you'), ('you', 'to'), ('to', 'the'), ('the', 'spot'), ('spot', 'and'), ('and', 'freezes'), ('freezes', 'the'), ('the', 'blood'), ('blood', 'coursing'), ('coursing', 'through'), ('through', 'your'), ('your', 'veins'), ('veins', 'she'), ('she', 'had'), ('had', 'woken'), ('woken', 'from'), ('from', 'this'), ('this', 'dream'), ('dream', 'with'), ('with', 'certainty'), ('certainty', 'she'), ('she', 'knew'), ('knew', 'what'), ('what', 'was'), ('was', 'coming'), ('coming', 'and'), ('and', 'she'), ('she', 'had'), ('had', 'been'), ('been', 'right')]
# Segment 1 - The Funeral and the Feast - Trigrams:
# [('the', 'old', 'woman'), ('old', 'woman', 'in'), ('woman', 'in', 'a'), ('in', 'a', 'white'), ('a', 'white', 'lace'), ('white', 'lace', 'dress'), ('lace', 'dress', 'had'), ('dress', 'had', 'appeared'), ('had', 'appeared', 'in'), ('appeared', 'in', 'claudias'), ('in', 'claudias', 'dream'), ('claudias', 'dream', 'three'), ('dream', 'three', 'days'), ('three', 'days', 'before'), ('days', 'before', 'her'), ('before', 'her', 'grandfather'), ('her', 'grandfather', 'died'), ('grandfather', 'died', 'the'), ('died', 'the', 'dress'), ('the', 'dress', 'was'), ('dress', 'was', 'so'), ('was', 'so', 'crisp'), ('so', 'crisp', 'so'), ('crisp', 'so', 'white'), ('so', 'white', 'so'), ('white', 'so', 'beautiful'), ('so', 'beautiful', 'it'), ('beautiful', 'it', 'actually'), ('it', 'actually', 'frightened'), ('actually', 'frightened', 'her'), ('frightened', 'her', 'not'), ('her', 'not', 'the'), ('not', 'the', 'kind'), ('the', 'kind', 'of'), ('kind', 'of', 'fear'), ('of', 'fear', 'that'), ('fear', 'that', 'makes'), ('that', 'makes', 'you'), ('makes', 'you', 'want'), ('you', 'want', 'to'), ('want', 'to', 'pull'), ('to', 'pull', 'the'), ('pull', 'the', 'blanket'), ('the', 'blanket', 'over'), ('blanket', 'over', 'your'), ('over', 'your', 'head'), ('your', 'head', 'but'), ('head', 'but', 'the'), ('but', 'the', 'kind'), ('the', 'kind', 'that'), ('kind', 'that', 'roots'), ('that', 'roots', 'you'), ('roots', 'you', 'to'), ('you', 'to', 'the'), ('to', 'the', 'spot'), ('the', 'spot', 'and'), ('spot', 'and', 'freezes'), ('and', 'freezes', 'the'), ('freezes', 'the', 'blood'), ('the', 'blood', 'coursing'), ('blood', 'coursing', 'through'), ('coursing', 'through', 'your'), ('through', 'your', 'veins'), ('your', 'veins', 'she'), ('veins', 'she', 'had'), ('she', 'had', 'woken'), ('had', 'woken', 'from'), ('woken', 'from', 'this'), ('from', 'this', 'dream'), ('this', 'dream', 'with'), ('dream', 'with', 'certainty'), ('with', 'certainty', 'she'), ('certainty', 'she', 'knew'), ('she', 'knew', 'what'), ('knew', 'what', 'was'), ('what', 'was', 'coming'), ('was', 'coming', 'and'), ('coming', 'and', 'she'), ('and', 'she', 'had'), ('she', 'had', 'been'), ('had', 'been', 'right')]
#
#
# Segment 2 - The Funeral and the Feast - Unigrams:
# [('claudia',), ('noticed',), ('her',), ('mother',), ('and',), ('said',), ('nothing',), ('she',), ('had',), ('spent',), ('the',), ('whole',), ('day',), ('calculating',), ('the',), ('right',), ('gesture',), ('a',), ('hand',), ('on',), ('the',), ('arm',), ('a',), ('quiet',), ('word',), ('of',), ('comfort',), ('and',), ('kept',), ('coming',), ('up',), ('empty',), ('for',), ('anyone',), ('else',), ('in',), ('mourning',), ('she',), ('would',), ('have',), ('known',), ('exactly',), ('what',), ('to',), ('do',), ('and',), ('say',), ('for',), ('her',), ('mother',), ('the',), ('wires',), ('crossed',), ('somewhere',), ('they',), ('seemed',), ('to',), ('always',), ('be',), ('reaching',), ('for',), ('each',), ('other',), ('but',), ('missing',), ('the',), ('mark',), ('by',), ('an',), ('inch',)]
# Segment 2 - The Funeral and the Feast - Bigrams:
# [('claudia', 'noticed'), ('noticed', 'her'), ('her', 'mother'), ('mother', 'and'), ('and', 'said'), ('said', 'nothing'), ('nothing', 'she'), ('she', 'had'), ('had', 'spent'), ('spent', 'the'), ('the', 'whole'), ('whole', 'day'), ('day', 'calculating'), ('calculating', 'the'), ('the', 'right'), ('right', 'gesture'), ('gesture', 'a'), ('a', 'hand'), ('hand', 'on'), ('on', 'the'), ('the', 'arm'), ('arm', 'a'), ('a', 'quiet'), ('quiet', 'word'), ('word', 'of'), ('of', 'comfort'), ('comfort', 'and'), ('and', 'kept'), ('kept', 'coming'), ('coming', 'up'), ('up', 'empty'), ('empty', 'for'), ('for', 'anyone'), ('anyone', 'else'), ('else', 'in'), ('in', 'mourning'), ('mourning', 'she'), ('she', 'would'), ('would', 'have'), ('have', 'known'), ('known', 'exactly'), ('exactly', 'what'), ('what', 'to'), ('to', 'do'), ('do', 'and'), ('and', 'say'), ('say', 'for'), ('for', 'her'), ('her', 'mother'), ('mother', 'the'), ('the', 'wires'), ('wires', 'crossed'), ('crossed', 'somewhere'), ('somewhere', 'they'), ('they', 'seemed'), ('seemed', 'to'), ('to', 'always'), ('always', 'be'), ('be', 'reaching'), ('reaching', 'for'), ('for', 'each'), ('each', 'other'), ('other', 'but'), ('but', 'missing'), ('missing', 'the'), ('the', 'mark'), ('mark', 'by'), ('by', 'an'), ('an', 'inch')]
# Segment 2 - The Funeral and the Feast - Trigrams:
# [('claudia', 'noticed', 'her'), ('noticed', 'her', 'mother'), ('her', 'mother', 'and'), ('mother', 'and', 'said'), ('and', 'said', 'nothing'), ('said', 'nothing', 'she'), ('nothing', 'she', 'had'), ('she', 'had', 'spent'), ('had', 'spent', 'the'), ('spent', 'the', 'whole'), ('the', 'whole', 'day'), ('whole', 'day', 'calculating'), ('day', 'calculating', 'the'), ('calculating', 'the', 'right'), ('the', 'right', 'gesture'), ('right', 'gesture', 'a'), ('gesture', 'a', 'hand'), ('a', 'hand', 'on'), ('hand', 'on', 'the'), ('on', 'the', 'arm'), ('the', 'arm', 'a'), ('arm', 'a', 'quiet'), ('a', 'quiet', 'word'), ('quiet', 'word', 'of'), ('word', 'of', 'comfort'), ('of', 'comfort', 'and'), ('comfort', 'and', 'kept'), ('and', 'kept', 'coming'), ('kept', 'coming', 'up'), ('coming', 'up', 'empty'), ('up', 'empty', 'for'), ('empty', 'for', 'anyone'), ('for', 'anyone', 'else'), ('anyone', 'else', 'in'), ('else', 'in', 'mourning'), ('in', 'mourning', 'she'), ('mourning', 'she', 'would'), ('she', 'would', 'have'), ('would', 'have', 'known'), ('have', 'known', 'exactly'), ('known', 'exactly', 'what'), ('exactly', 'what', 'to'), ('what', 'to', 'do'), ('to', 'do', 'and'), ('do', 'and', 'say'), ('and', 'say', 'for'), ('say', 'for', 'her'), ('for', 'her', 'mother'), ('her', 'mother', 'the'), ('mother', 'the', 'wires'), ('the', 'wires', 'crossed'), ('wires', 'crossed', 'somewhere'), ('crossed', 'somewhere', 'they'), ('somewhere', 'they', 'seemed'), ('they', 'seemed', 'to'), ('seemed', 'to', 'always'), ('to', 'always', 'be'), ('always', 'be', 'reaching'), ('be', 'reaching', 'for'), ('reaching', 'for', 'each'), ('for', 'each', 'other'), ('each', 'other', 'but'), ('other', 'but', 'missing'), ('but', 'missing', 'the'), ('missing', 'the', 'mark'), ('the', 'mark', 'by'), ('mark', 'by', 'an'), ('by', 'an', 'inch')]
#
#
# Segment 3 - The Funeral and the Feast - Unigrams:
# [('on',), ('her',), ('left',), ('sat',), ('ninety',), ('three',), ('years',), ('old',), ('victor',), ('who',), ('had',), ('been',), ('friends',), ('with',), ('her',), ('grandfather',), ('for',), ('longer',), ('than',), ('claudias',), ('parents',), ('had',), ('been',), ('alive',), ('he',), ('was',), ('the',), ('spitting',), ('image',), ('of',), ('french',), ('movie',), ('star',), ('from',), ('the',), ('80s',), ('and',), ('90s',), ('the',), ('beautiful',), ('alain',), ('delon',), ('the',), ('man',), ('was',), ('over',), ('six',), ('feet',), ('tall',), ('full',), ('head',), ('of',), ('silver',), ('hair',), ('cleanly',), ('shaven',), ('and',), ('looking',), ('dapper',), ('in',), ('his',), ('leather',), ('jacket',), ('and',), ('suit',), ('pants',), ('it',), ('was',), ('easy',), ('for',), ('claudia',), ('to',), ('assume',), ('that',), ('her',), ('grandfather',), ('and',), ('this',), ('man',), ('were',), ('quite',), ('the',), ('casanovas',), ('back',), ('in',), ('the',), ('day',)]
# Segment 3 - The Funeral and the Feast - Bigrams:
# [('on', 'her'), ('her', 'left'), ('left', 'sat'), ('sat', 'ninety'), ('ninety', 'three'), ('three', 'years'), ('years', 'old'), ('old', 'victor'), ('victor', 'who'), ('who', 'had'), ('had', 'been'), ('been', 'friends'), ('friends', 'with'), ('with', 'her'), ('her', 'grandfather'), ('grandfather', 'for'), ('for', 'longer'), ('longer', 'than'), ('than', 'claudias'), ('claudias', 'parents'), ('parents', 'had'), ('had', 'been'), ('been', 'alive'), ('alive', 'he'), ('he', 'was'), ('was', 'the'), ('the', 'spitting'), ('spitting', 'image'), ('image', 'of'), ('of', 'french'), ('french', 'movie'), ('movie', 'star'), ('star', 'from'), ('from', 'the'), ('the', '80s'), ('80s', 'and'), ('and', '90s'), ('90s', 'the'), ('the', 'beautiful'), ('beautiful', 'alain'), ('alain', 'delon'), ('delon', 'the'), ('the', 'man'), ('man', 'was'), ('was', 'over'), ('over', 'six'), ('six', 'feet'), ('feet', 'tall'), ('tall', 'full'), ('full', 'head'), ('head', 'of'), ('of', 'silver'), ('silver', 'hair'), ('hair', 'cleanly'), ('cleanly', 'shaven'), ('shaven', 'and'), ('and', 'looking'), ('looking', 'dapper'), ('dapper', 'in'), ('in', 'his'), ('his', 'leather'), ('leather', 'jacket'), ('jacket', 'and'), ('and', 'suit'), ('suit', 'pants'), ('pants', 'it'), ('it', 'was'), ('was', 'easy'), ('easy', 'for'), ('for', 'claudia'), ('claudia', 'to'), ('to', 'assume'), ('assume', 'that'), ('that', 'her'), ('her', 'grandfather'), ('grandfather', 'and'), ('and', 'this'), ('this', 'man'), ('man', 'were'), ('were', 'quite'), ('quite', 'the'), ('the', 'casanovas'), ('casanovas', 'back'), ('back', 'in'), ('in', 'the'), ('the', 'day')]
# Segment 3 - The Funeral and the Feast - Trigrams:
# [('on', 'her', 'left'), ('her', 'left', 'sat'), ('left', 'sat', 'ninety'), ('sat', 'ninety', 'three'), ('ninety', 'three', 'years'), ('three', 'years', 'old'), ('years', 'old', 'victor'), ('old', 'victor', 'who'), ('victor', 'who', 'had'), ('who', 'had', 'been'), ('had', 'been', 'friends'), ('been', 'friends', 'with'), ('friends', 'with', 'her'), ('with', 'her', 'grandfather'), ('her', 'grandfather', 'for'), ('grandfather', 'for', 'longer'), ('for', 'longer', 'than'), ('longer', 'than', 'claudias'), ('than', 'claudias', 'parents'), ('claudias', 'parents', 'had'), ('parents', 'had', 'been'), ('had', 'been', 'alive'), ('been', 'alive', 'he'), ('alive', 'he', 'was'), ('he', 'was', 'the'), ('was', 'the', 'spitting'), ('the', 'spitting', 'image'), ('spitting', 'image', 'of'), ('image', 'of', 'french'), ('of', 'french', 'movie'), ('french', 'movie', 'star'), ('movie', 'star', 'from'), ('star', 'from', 'the'), ('from', 'the', '80s'), ('the', '80s', 'and'), ('80s', 'and', '90s'), ('and', '90s', 'the'), ('90s', 'the', 'beautiful'), ('the', 'beautiful', 'alain'), ('beautiful', 'alain', 'delon'), ('alain', 'delon', 'the'), ('delon', 'the', 'man'), ('the', 'man', 'was'), ('man', 'was', 'over'), ('was', 'over', 'six'), ('over', 'six', 'feet'), ('six', 'feet', 'tall'), ('feet', 'tall', 'full'), ('tall', 'full', 'head'), ('full', 'head', 'of'), ('head', 'of', 'silver'), ('of', 'silver', 'hair'), ('silver', 'hair', 'cleanly'), ('hair', 'cleanly', 'shaven'), ('cleanly', 'shaven', 'and'), ('shaven', 'and', 'looking'), ('and', 'looking', 'dapper'), ('looking', 'dapper', 'in'), ('dapper', 'in', 'his'), ('in', 'his', 'leather'), ('his', 'leather', 'jacket'), ('leather', 'jacket', 'and'), ('jacket', 'and', 'suit'), ('and', 'suit', 'pants'), ('suit', 'pants', 'it'), ('pants', 'it', 'was'), ('it', 'was', 'easy'), ('was', 'easy', 'for'), ('easy', 'for', 'claudia'), ('for', 'claudia', 'to'), ('claudia', 'to', 'assume'), ('to', 'assume', 'that'), ('assume', 'that', 'her'), ('that', 'her', 'grandfather'), ('her', 'grandfather', 'and'), ('grandfather', 'and', 'this'), ('and', 'this', 'man'), ('this', 'man', 'were'), ('man', 'were', 'quite'), ('were', 'quite', 'the'), ('quite', 'the', 'casanovas'), ('the', 'casanovas', 'back'), ('casanovas', 'back', 'in'), ('back', 'in', 'the'), ('in', 'the', 'day')]

# %% [markdown]
# ***
# Jen Allen<br>
# CST 645 100 Natural Language Processing<br>
# Week 3 Assignment<br>
# 05/31/2026<br>
# <br>
# **GitHub:** https://github.com/JeaneeAllen/N-grams_NLTK
